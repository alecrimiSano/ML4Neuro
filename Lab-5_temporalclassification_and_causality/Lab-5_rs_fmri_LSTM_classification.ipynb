# %% [markdown]
# ## Using LSTM to analyze resting state networks
#
# This notebook includes code to classify ADHD from healthy controls using LSTM model with rs-fMRI data.

# %% [markdown]
# First let's import the relevant libraries

# %%
# !pip install nilearn
from nilearn import datasets
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
plt.style.use('ggplot')

#nilearn - neuroimaging tailored library
from nilearn.input_data import NiftiMapsMasker
from nilearn import plotting

#sklearn - basic ML tools
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn import metrics

#keras - for NN models
from keras.models import Model, Sequential
from keras.layers import Input, Dense
from keras.layers import LSTM
from keras import optimizers
from keras.utils import plot_model
from keras import utils
from sklearn.metrics import roc_curve


#scipy- statistical analysis tools
from scipy.stats import ttest_1samp
from scipy import interp
# Out:
# Collecting nilearn
#   Downloading nilearn-0.10.2-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 48.7 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.3.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nilearn) (4.9.3)
# Requirement already satisfied: nibabel>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (4.0.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nilearn) (23.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.5.3)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (2.31.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.2.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from nilearn) (1.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel>=3.2.0->nilearn) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->nilearn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->nilearn) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->nilearn) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->nilearn) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->nilearn) (1.16.0)
# Installing collected packages: nilearn
# Successfully installed nilearn-0.10.2

# %% [markdown]
# ## Preparing data for analysis ##
#
# Import data, and exctract features

# %%
## load the smith (ICA based) mask
## 'rsn10': 10 ICA maps from the above that matched across task and rest
# http://brainmap.org/pubs/SmithPNAS09.pdf

smith_atlas = datasets.fetch_atlas_smith_2009()
smith_atlas_rs_networks = smith_atlas.rsn70
# Out:
# Dataset created in /root/nilearn_data/smith_2009
#
# Downloading data from https://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/rsn20.nii.gz ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/PNAS_Smith09_rsn10.nii.gz ...
#  ...done. (0 seconds, 0 min)
# Downloading data from https://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/rsn70.nii.gz ...
# Downloaded 43433984 of 53028809 bytes (81.9%,    0.2s remaining) ...done. (1 seconds, 0 min)
# Downloading data from https://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/bm20.nii.gz ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/PNAS_Smith09_bm10.nii.gz ...
#  ...done. (0 seconds, 0 min)
# Downloading data from https://www.fmrib.ox.ac.uk/datasets/brainmap+rsns/bm70.nii.gz ...
# Downloaded 61333504 of 67017538 bytes (91.5%,    0.3s remaining) ...done. (4 seconds, 0 min)

# %%
plotting.plot_prob_atlas(smith_atlas_rs_networks,
                         title='Smith atlas',
                         colorbar=True)
plotting.show()

# %%
# Import preprocessed, ready-to-go, datasets
adhd_data=datasets.fetch_adhd(n_subjects=100)
# Out:
# Dataset created in /root/nilearn_data/adhd
#
# Downloading data from https://www.nitrc.org/frs/download.php/7781/adhd40_metadata.tgz ...
#  ...done. (0 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/fbef5baff0b388a8c913a08e1d84e059/adhd40_metadata.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7782/adhd40_0010042.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_0010042.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7783/adhd40_0010064.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_0010064.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7784/adhd40_0010128.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_0010128.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7785/adhd40_0021019.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_0021019.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7786/adhd40_0023008.tgz ...
#  ...done. (0 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_0023008.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7787/adhd40_0023012.tgz ...
#  ...done. (0 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_0023012.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7788/adhd40_0027011.tgz ...
# Downloaded 55164928 of 72402326 bytes (76.2%,    0.3s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_0027011.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7789/adhd40_0027018.tgz ...
# Downloaded 54239232 of 76184603 bytes (71.2%,    0.4s remaining) ...done. (2 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_0027018.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7790/adhd40_0027034.tgz ...
# Downloaded 59539456 of 70074120 bytes (85.0%,    0.2s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_0027034.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7791/adhd40_0027037.tgz ...
# Downloaded 49709056 of 69291635 bytes (71.7%,    0.4s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_0027037.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7792/adhd40_1019436.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_1019436.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7793/adhd40_1206380.tgz ...
#  ...done. (0 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_1206380.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7794/adhd40_1418396.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_1418396.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7795/adhd40_1517058.tgz ...
# Downloaded 55812096 of 62682233 bytes (89.0%,    0.1s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_1517058.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7796/adhd40_1552181.tgz ...
#  ...done. (0 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_1552181.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7797/adhd40_1562298.tgz ...
# Downloaded 51232768 of 60663491 bytes (84.5%,    0.2s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_1562298.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7798/adhd40_1679142.tgz ...
#  ...done. (0 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_1679142.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7799/adhd40_2014113.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_2014113.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7800/adhd40_2497695.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_2497695.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7801/adhd40_2950754.tgz ...
# Downloaded 57384960 of 57992968 bytes (99.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_2950754.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7802/adhd40_3007585.tgz ...
# Downloaded 54657024 of 67925261 bytes (80.5%,    0.2s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_3007585.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7803/adhd40_3154996.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_3154996.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7804/adhd40_3205761.tgz ...
# Downloaded 57458688 of 59835286 bytes (96.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_3205761.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7805/adhd40_3520880.tgz ...
# Downloaded 51888128 of 61857076 bytes (83.9%,    0.2s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_3520880.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7806/adhd40_3624598.tgz ...
# Downloaded 45907968 of 59385206 bytes (77.3%,    0.3s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_3624598.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7807/adhd40_3699991.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_3699991.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7808/adhd40_3884955.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_3884955.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7809/adhd40_3902469.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_3902469.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7810/adhd40_3994098.tgz ...
# Downloaded 57262080 of 59297020 bytes (96.6%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_3994098.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7811/adhd40_4016887.tgz ...
#  ...done. (0 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_4016887.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7812/adhd40_4046678.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_4046678.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7813/adhd40_4134561.tgz ...
# Downloaded 51650560 of 69914913 bytes (73.9%,    0.4s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_4134561.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7814/adhd40_4164316.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_4164316.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7815/adhd40_4275075.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_4275075.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7816/adhd40_6115230.tgz ...
# Downloaded 51757056 of 73484949 bytes (70.4%,    0.4s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_6115230.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7817/adhd40_7774305.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_7774305.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7818/adhd40_8409791.tgz ...
# Downloaded 55566336 of 70396354 bytes (78.9%,    0.3s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_8409791.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7819/adhd40_8697774.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_8697774.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7820/adhd40_9744150.tgz ...
# Downloaded 59883520 of 63380505 bytes (94.5%,    0.1s remaining) ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_9744150.tgz..... done.
# Downloading data from https://www.nitrc.org/frs/download.php/7821/adhd40_9750701.tgz ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/adhd/49718167d83b032094ad6d17e64b4e49/adhd40_9750701.tgz..... done.

# %%
# exploring the header of one image
import nibabel as nib
img=nib.load(adhd_data['func'][0])

print(img.header['dim'])
print(img.header['pixdim'])
# Out:
# [  4  61  73  61 176   1   1   1]
# [-1.  3.  3.  3.  2.  0.  0.  0.]

# %%
# Region signals extraction- exctract the values of the ten networks

masker = NiftiMapsMasker(maps_img=smith_atlas_rs_networks,  # Smith stals
                         standardize=True, # centers and norms the time-series
                         memory='nilearn_cache', # cache
                         verbose=0) #do not print verbose

# %%
all_subjects_data=[]
labels=[]  # 1 if ADHD, 0 if control

for func_file, confound_file, phenotypic in zip(
        adhd_data.func, adhd_data.confounds, adhd_data.phenotypic):

    time_series = masker.fit_transform(func_file, confounds=confound_file)

    all_subjects_data.append(time_series)
    labels.append(phenotypic['adhd'])

# %%
print('N control:' ,labels.count(0))
print('N adhd:' ,labels.count(1))

# %%
plt.hist([len(i) for i in all_subjects_data])
plt.title('fMRI dataset length variation')
plt.xlabel('time stamps')
plt.ylabel('#')
plt.show()

# %%
# find the longest image
max_len_image=np.max([len(i) for i in all_subjects_data])

# %%
# reshape

all_subjects_data_reshaped=[]
for subject_data in all_subjects_data:
  # Padding
  N= max_len_image-len(subject_data)
  padded_array=np.pad(subject_data, ((0, N), (0,0)),
                      'constant', constant_values=(0))
  subject_data=padded_array
  subject_data=np.array(subject_data)
  subject_data.reshape(subject_data.shape[0],subject_data.shape[1],1)
  all_subjects_data_reshaped.append(subject_data)

# %%
# shape of data

# 40 subjects
# 261 time stamps
# 10 netwroks values

np.array(all_subjects_data_reshaped).shape
# Out:
# (40, 261, 70)

# %%
# The data, split between train and test sets.

def get_train_test(X, y, i, verbrose=False):
  '''
  split to train and test and reshape data
  X data
  y labels
  i random state
  '''
  X_train, X_test, y_train, y_test = train_test_split(X,
                                        y, test_size=0.2, random_state=i)



  # Reshapes data to 4D for Hierarchical RNN.
  t_shape=np.array(all_subjects_data_reshaped).shape[1]
  RSN_shape=np.array(all_subjects_data_reshaped).shape[2]

  X_train = np.reshape(X_train, (len(X_train), t_shape, RSN_shape))
  X_test = np.reshape(X_test, (len(X_test), t_shape, RSN_shape))

  X_train = X_train.astype('float32')
  X_test = X_test.astype('float32')

  if verbrose:
    print(X_train.shape[0], 'train samples')
    print(X_test.shape[0], 'test samples')

  # Converts class vectors to binary class matrices.
  y_train = utils.to_categorical(y_train, 2)
  y_test = utils.to_categorical(y_test, 2)

  return X_train, X_test, y_train, y_test
# Out:
# 32 train samples
# 8 test samples

# %% [markdown]
# ## Build the LSTM model

# %%
# create the model

model = Sequential()

# LSTM layers -
# Long Short-Term Memory layer - Hochreiter 1997.
t_shape=np.array(all_subjects_data_reshaped).shape[1]
RSN_shape=np.array(all_subjects_data_reshaped).shape[2]

model.add(LSTM(units=70, # dimensionality of the output space
               dropout=0.4, # Fraction of the units to drop (inputs)
               recurrent_dropout=0.15, # Fraction of the units to drop (recurent state)
               return_sequences=True, # return the last state in addition to the output
               input_shape=(t_shape,RSN_shape)))

model.add(LSTM(units=60,
               dropout=0.4,
               recurrent_dropout=0.15,
               return_sequences=True))

model.add(LSTM(units=50,
               dropout=0.4,
               recurrent_dropout=0.15,
               return_sequences=True))

model.add(LSTM(units=40,
               dropout=0.4,
               recurrent_dropout=0.15,
               return_sequences=False))


model.add(Dense(units=2,
                activation="sigmoid"))

model.compile(loss='binary_crossentropy',
                optimizer=optimizers.Adam(lr=0.001),
                metrics=['binary_accuracy'])

print(model.summary())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 261, 70)           39480
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 261, 60)           31440
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 261, 50)           22200
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 40)                14560
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 82
# =================================================================
# Total params: 107,762
# Trainable params: 107,762
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Train the LSTM model

# %%
X_train, X_test, y_train, y_test = get_train_test(all_subjects_data_reshaped,
                                                    labels, i=8, verbrose=True)

history = model.fit(X_train, y_train, validation_split=0.2, epochs=30)

# summarize history for accuracy
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# 32 train samples
# 8 test samples
# Train on 25 samples, validate on 7 samples
# Epoch 1/30
# 25/25 [==============================] - 2s 100ms/step - loss: 0.6885 - binary_accuracy: 0.5600 - val_loss: 0.6926 - val_binary_accuracy: 0.5714
# Epoch 2/30
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6929 - binary_accuracy: 0.5800 - val_loss: 0.6925 - val_binary_accuracy: 0.5714
# Epoch 3/30
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6929 - binary_accuracy: 0.5800 - val_loss: 0.6921 - val_binary_accuracy: 0.5714
# Epoch 4/30
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6881 - binary_accuracy: 0.6000 - val_loss: 0.6919 - val_binary_accuracy: 0.5714
# Epoch 5/30
# 25/25 [==============================] - 1s 25ms/step - loss: 0.6813 - binary_accuracy: 0.6200 - val_loss: 0.6914 - val_binary_accuracy: 0.5714
# Epoch 6/30
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6774 - binary_accuracy: 0.6200 - val_loss: 0.6905 - val_binary_accuracy: 0.5714
# Epoch 7/30
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6806 - binary_accuracy: 0.5800 - val_loss: 0.6895 - val_binary_accuracy: 0.5714
# Epoch 8/30
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6786 - binary_accuracy: 0.6400 - val_loss: 0.6882 - val_binary_accuracy: 0.5714
# Epoch 9/30
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6837 - binary_accuracy: 0.5800 - val_loss: 0.6867 - val_binary_accuracy: 0.5714
# Epoch 10/30
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6724 - binary_accuracy: 0.6200 - val_loss: 0.6854 - val_binary_accuracy: 0.5714
# Epoch 11/30
# 25/25 [==============================] - 1s 25ms/step - loss: 0.6632 - binary_accuracy: 0.6200 - val_loss: 0.6836 - val_binary_accuracy: 0.5714
# Epoch 12/30
# 25/25 [==============================] - 1s 29ms/step - loss: 0.6698 - binary_accuracy: 0.5800 - val_loss: 0.6815 - val_binary_accuracy: 0.5714
# Epoch 13/30
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6626 - binary_accuracy: 0.6200 - val_loss: 0.6790 - val_binary_accuracy: 0.5714
# Epoch 14/30
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6610 - binary_accuracy: 0.6800 - val_loss: 0.6758 - val_binary_accuracy: 0.5714
# Epoch 15/30
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6657 - binary_accuracy: 0.6000 - val_loss: 0.6723 - val_binary_accuracy: 0.5714
# Epoch 16/30
# 25/25 [==============================] - 1s 27ms/step - loss: 0.6879 - binary_accuracy: 0.6000 - val_loss: 0.6696 - val_binary_accuracy: 0.5714
# Epoch 17/30
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6694 - binary_accuracy: 0.6400 - val_loss: 0.6672 - val_binary_accuracy: 0.5714
# Epoch 18/30
# 25/25 [==============================] - 1s 26ms/step - loss: 0.6423 - binary_accuracy: 0.6200 - val_loss: 0.6630 - val_binary_accuracy: 0.5714
# Epoch 19/30
# 25/25 [==============================] - 1s 29ms/step - loss: 0.6476 - binary_accuracy: 0.6600 - val_loss: 0.6582 - val_binary_accuracy: 0.5714
# Epoch 20/30
# 25/25 [==============================] - 1s 29ms/step - loss: 0.6510 - binary_accuracy: 0.6400 - val_loss: 0.6529 - val_binary_accuracy: 0.5714
# Epoch 21/30
# 25/25 [==============================] - 1s 27ms/step - loss: 0.6163 - binary_accuracy: 0.6800 - val_loss: 0.6462 - val_binary_accuracy: 0.5714
# Epoch 22/30
# 25/25 [==============================] - 1s 26ms/step - loss: 0.5932 - binary_accuracy: 0.7200 - val_loss: 0.6368 - val_binary_accuracy: 0.6429
# Epoch 23/30
# 25/25 [==============================] - 1s 25ms/step - loss: 0.5996 - binary_accuracy: 0.6800 - val_loss: 0.6254 - val_binary_accuracy: 0.7143
# Epoch 24/30
# 25/25 [==============================] - 1s 29ms/step - loss: 0.5883 - binary_accuracy: 0.7200 - val_loss: 0.6128 - val_binary_accuracy: 0.7143
# Epoch 25/30
# 25/25 [==============================] - 1s 28ms/step - loss: 0.5739 - binary_accuracy: 0.7200 - val_loss: 0.5994 - val_binary_accuracy: 0.7143
# Epoch 26/30
# 25/25 [==============================] - 1s 26ms/step - loss: 0.5343 - binary_accuracy: 0.7600 - val_loss: 0.5833 - val_binary_accuracy: 0.7143
# Epoch 27/30
# 25/25 [==============================] - 1s 26ms/step - loss: 0.5521 - binary_accuracy: 0.7600 - val_loss: 0.5637 - val_binary_accuracy: 0.7143
# Epoch 28/30
# 25/25 [==============================] - 1s 30ms/step - loss: 0.5184 - binary_accuracy: 0.8000 - val_loss: 0.5391 - val_binary_accuracy: 0.7143
# Epoch 29/30
# 25/25 [==============================] - 1s 29ms/step - loss: 0.5613 - binary_accuracy: 0.6800 - val_loss: 0.5205 - val_binary_accuracy: 0.7143
# Epoch 30/30
# 25/25 [==============================] - 1s 26ms/step - loss: 0.4429 - binary_accuracy: 0.8000 - val_loss: 0.5010 - val_binary_accuracy: 0.7143

# %% [markdown]
# ## Evaluate the LSTM model

# %%
from sklearn.metrics import accuracy_score

def boostrapping_hypothesis_testing(X_train, y_train, X_test, y_test,
                                    n_iterations=100, n_epochs=50):

  '''
  hypothesis testing function
  X_train, y_train, X_test, y_test- the data
  n_iterations- number of bootdtaping iterations
  n_epochs - number of epochs for model's training
  '''

  accuracy=[] ## model accuracy
  roc_msrmnts_fpr=[] ## false positive rate
  roc_msrmnts_tpr=[] ## true positive rate

  # run bootstrap
  for i in range(n_iterations):
    # prepare train and test sets
    X_train, X_test, y_train, y_test=get_train_test(all_subjects_data_reshaped,
                                              labels, i=i, verbrose=False)
    # fit model
    print('fitting..')
    model.fit(X_train, y_train, validation_split=0.2, epochs=n_epochs)

    # evaluate model
    print('evaluating..')
    y_pred=model.predict(X_test)
    y_test_1d=[i[0] for i in y_test]
    y_pred_1d=[1.0 if i[0]>.5 else 0.0 for i in y_pred]

    fpr, tpr, _ = roc_curve(y_test_1d, y_pred_1d)

    acc_score = accuracy_score(y_test_1d, y_pred_1d)

    accuracy.append(acc_score)
    roc_msrmnts_fpr.append(fpr)
    roc_msrmnts_tpr.append(tpr)

  return accuracy, roc_msrmnts_fpr, roc_msrmnts_tpr



accuracy, roc_msrmnts_fpr, roc_msrmnts_tpr  = boostrapping_hypothesis_testing(X_train, y_train, X_test, y_test)
# Out:
# fitting..
# Train on 25 samples, validate on 7 samples
# Epoch 1/50
# 25/25 [==============================] - 1s 31ms/step - loss: 0.6721 - binary_accuracy: 0.5200 - val_loss: 0.6196 - val_binary_accuracy: 0.8571
# Epoch 2/50
# 25/25 [==============================] - 1s 27ms/step - loss: 0.6737 - binary_accuracy: 0.4600 - val_loss: 0.6170 - val_binary_accuracy: 0.8571
# Epoch 3/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6482 - binary_accuracy: 0.6200 - val_loss: 0.6151 - val_binary_accuracy: 0.8571
# Epoch 4/50
# 25/25 [==============================] - 1s 30ms/step - loss: 0.6489 - binary_accuracy: 0.5800 - val_loss: 0.6145 - val_binary_accuracy: 0.8571
# Epoch 5/50
# 25/25 [==============================] - 1s 36ms/step - loss: 0.6650 - binary_accuracy: 0.6000 - val_loss: 0.6156 - val_binary_accuracy: 0.8571
# Epoch 6/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.6448 - binary_accuracy: 0.6000 - val_loss: 0.6178 - val_binary_accuracy: 0.8571
# Epoch 7/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.6397 - binary_accuracy: 0.6200 - val_loss: 0.6212 - val_binary_accuracy: 0.8571
# Epoch 8/50
# 25/25 [==============================] - 1s 32ms/step - loss: 0.6474 - binary_accuracy: 0.5400 - val_loss: 0.6249 - val_binary_accuracy: 0.7857
# Epoch 9/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6426 - binary_accuracy: 0.5800 - val_loss: 0.6302 - val_binary_accuracy: 0.6429
# Epoch 10/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.6206 - binary_accuracy: 0.4800 - val_loss: 0.6360 - val_binary_accuracy: 0.5714
# Epoch 11/50
# 25/25 [==============================] - 1s 35ms/step - loss: 0.6298 - binary_accuracy: 0.6400 - val_loss: 0.6425 - val_binary_accuracy: 0.5714
# Epoch 12/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.6279 - binary_accuracy: 0.6400 - val_loss: 0.6487 - val_binary_accuracy: 0.5714
# Epoch 13/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.6534 - binary_accuracy: 0.6200 - val_loss: 0.6549 - val_binary_accuracy: 0.5714
# Epoch 14/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.6415 - binary_accuracy: 0.6600 - val_loss: 0.6600 - val_binary_accuracy: 0.4286
# Epoch 15/50
# 25/25 [==============================] - 1s 33ms/step - loss: 0.5858 - binary_accuracy: 0.6800 - val_loss: 0.6657 - val_binary_accuracy: 0.4286
# Epoch 16/50
# 25/25 [==============================] - 1s 29ms/step - loss: 0.6461 - binary_accuracy: 0.5400 - val_loss: 0.6708 - val_binary_accuracy: 0.4286
# Epoch 17/50
# 25/25 [==============================] - 1s 31ms/step - loss: 0.6134 - binary_accuracy: 0.6400 - val_loss: 0.6777 - val_binary_accuracy: 0.4286
# Epoch 18/50
# 25/25 [==============================] - 1s 30ms/step - loss: 0.5976 - binary_accuracy: 0.6800 - val_loss: 0.6838 - val_binary_accuracy: 0.4286
# Epoch 19/50
# 25/25 [==============================] - 1s 28ms/step - loss: 0.6028 - binary_accuracy: 0.6400 - val_loss: 0.6865 - val_binary_accuracy: 0.4286
# Epoch 20/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.6071 - binary_accuracy: 0.6000 - val_loss: 0.6936 - val_binary_accuracy: 0.4286
# Epoch 21/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5996 - binary_accuracy: 0.6800 - val_loss: 0.6980 - val_binary_accuracy: 0.4286
# Epoch 22/50
# 25/25 [==============================] - 1s 28ms/step - loss: 0.5807 - binary_accuracy: 0.6800 - val_loss: 0.7012 - val_binary_accuracy: 0.4286
# Epoch 23/50
# 25/25 [==============================] - 1s 38ms/step - loss: 0.5752 - binary_accuracy: 0.6400 - val_loss: 0.7040 - val_binary_accuracy: 0.4286
# Epoch 24/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.5751 - binary_accuracy: 0.6800 - val_loss: 0.7037 - val_binary_accuracy: 0.4286
# Epoch 25/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5740 - binary_accuracy: 0.6800 - val_loss: 0.7018 - val_binary_accuracy: 0.4286
# Epoch 26/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.6090 - binary_accuracy: 0.6600 - val_loss: 0.6955 - val_binary_accuracy: 0.4286
# Epoch 27/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5622 - binary_accuracy: 0.7200 - val_loss: 0.6832 - val_binary_accuracy: 0.4286
# Epoch 28/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5377 - binary_accuracy: 0.7000 - val_loss: 0.6697 - val_binary_accuracy: 0.4286
# Epoch 29/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5869 - binary_accuracy: 0.6400 - val_loss: 0.6537 - val_binary_accuracy: 0.4286
# Epoch 30/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5467 - binary_accuracy: 0.7200 - val_loss: 0.6372 - val_binary_accuracy: 0.4286
# Epoch 31/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5774 - binary_accuracy: 0.6000 - val_loss: 0.6325 - val_binary_accuracy: 0.4286
# Epoch 32/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5618 - binary_accuracy: 0.7200 - val_loss: 0.6362 - val_binary_accuracy: 0.4286
# Epoch 33/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.6023 - binary_accuracy: 0.6800 - val_loss: 0.6402 - val_binary_accuracy: 0.4286
# Epoch 34/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5392 - binary_accuracy: 0.7400 - val_loss: 0.6460 - val_binary_accuracy: 0.4286
# Epoch 35/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5716 - binary_accuracy: 0.7200 - val_loss: 0.6461 - val_binary_accuracy: 0.4286
# Epoch 36/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5619 - binary_accuracy: 0.6600 - val_loss: 0.6439 - val_binary_accuracy: 0.4286
# Epoch 37/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5662 - binary_accuracy: 0.6800 - val_loss: 0.6337 - val_binary_accuracy: 0.4286
# Epoch 38/50
# 25/25 [==============================] - 1s 34ms/step - loss: 0.5773 - binary_accuracy: 0.5200 - val_loss: 0.6201 - val_binary_accuracy: 0.5714
# Epoch 39/50
# 25/25 [==============================] - 1s 28ms/step - loss: 0.5037 - binary_accuracy: 0.8400 - val_loss: 0.6117 - val_binary_accuracy: 0.5714
# Epoch 40/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5142 - binary_accuracy: 0.6400 - val_loss: 0.6063 - val_binary_accuracy: 0.5714
# Epoch 41/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5577 - binary_accuracy: 0.7000 - val_loss: 0.6097 - val_binary_accuracy: 0.5714
# Epoch 42/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5458 - binary_accuracy: 0.6000 - val_loss: 0.6174 - val_binary_accuracy: 0.5714
# Epoch 43/50
# 25/25 [==============================] - 1s 28ms/step - loss: 0.5634 - binary_accuracy: 0.6600 - val_loss: 0.6287 - val_binary_accuracy: 0.5714
# Epoch 44/50
# 25/25 [==============================] - 1s 28ms/step - loss: 0.5155 - binary_accuracy: 0.8000 - val_loss: 0.6419 - val_binary_accuracy: 0.5714
# Epoch 45/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.5852 - binary_accuracy: 0.5400 - val_loss: 0.6592 - val_binary_accuracy: 0.5714
# Epoch 46/50
# 25/25 [==============================] - 1s 41ms/step - loss: 0.5031 - binary_accuracy: 0.7200 - val_loss: 0.6783 - val_binary_accuracy: 0.5714
# Epoch 47/50
# 25/25 [==============================] - 1s 31ms/step - loss: 0.5867 - binary_accuracy: 0.5400 - val_loss: 0.7067 - val_binary_accuracy: 0.4286
# Epoch 48/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5253 - binary_accuracy: 0.7200 - val_loss: 0.7437 - val_binary_accuracy: 0.4286
# Epoch 49/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4745 - binary_accuracy: 0.7200 - val_loss: 0.7855 - val_binary_accuracy: 0.4286
# Epoch 50/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5256 - binary_accuracy: 0.6600 - val_loss: 0.8323 - val_binary_accuracy: 0.4286
# evaluating..
# fitting..
# Train on 25 samples, validate on 7 samples
# Epoch 1/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.6075 - binary_accuracy: 0.5600 - val_loss: 0.5292 - val_binary_accuracy: 0.5714
# Epoch 2/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.5261 - binary_accuracy: 0.6400 - val_loss: 0.5319 - val_binary_accuracy: 0.5714
# Epoch 3/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5517 - binary_accuracy: 0.6400 - val_loss: 0.5301 - val_binary_accuracy: 0.5714
# Epoch 4/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.7959 - binary_accuracy: 0.5800 - val_loss: 0.5222 - val_binary_accuracy: 0.5714
# Epoch 5/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.6901 - binary_accuracy: 0.6400 - val_loss: 0.5151 - val_binary_accuracy: 0.5714
# Epoch 6/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.6135 - binary_accuracy: 0.7000 - val_loss: 0.5075 - val_binary_accuracy: 0.5714
# Epoch 7/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.6760 - binary_accuracy: 0.5400 - val_loss: 0.4988 - val_binary_accuracy: 0.5714
# Epoch 8/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5643 - binary_accuracy: 0.5200 - val_loss: 0.4940 - val_binary_accuracy: 0.5714
# Epoch 9/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.6056 - binary_accuracy: 0.6000 - val_loss: 0.4901 - val_binary_accuracy: 0.5714
# Epoch 10/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.6779 - binary_accuracy: 0.5400 - val_loss: 0.4861 - val_binary_accuracy: 0.8571
# Epoch 11/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.5331 - binary_accuracy: 0.7400 - val_loss: 0.4834 - val_binary_accuracy: 0.8571
# Epoch 12/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5113 - binary_accuracy: 0.7600 - val_loss: 0.4815 - val_binary_accuracy: 0.8571
# Epoch 13/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.6107 - binary_accuracy: 0.6800 - val_loss: 0.4807 - val_binary_accuracy: 0.8571
# Epoch 14/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.5236 - binary_accuracy: 0.7200 - val_loss: 0.4803 - val_binary_accuracy: 0.8571
# Epoch 15/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5716 - binary_accuracy: 0.6400 - val_loss: 0.4803 - val_binary_accuracy: 0.8571
# Epoch 16/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5001 - binary_accuracy: 0.7200 - val_loss: 0.4800 - val_binary_accuracy: 0.8571
# Epoch 17/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5338 - binary_accuracy: 0.6800 - val_loss: 0.4793 - val_binary_accuracy: 0.8571
# Epoch 18/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5525 - binary_accuracy: 0.6800 - val_loss: 0.4781 - val_binary_accuracy: 0.8571
# Epoch 19/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5679 - binary_accuracy: 0.5800 - val_loss: 0.4771 - val_binary_accuracy: 0.8571
# Epoch 20/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.5926 - binary_accuracy: 0.5600 - val_loss: 0.4759 - val_binary_accuracy: 0.8571
# Epoch 21/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.6131 - binary_accuracy: 0.6800 - val_loss: 0.4748 - val_binary_accuracy: 0.8571
# Epoch 22/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.5600 - binary_accuracy: 0.6800 - val_loss: 0.4742 - val_binary_accuracy: 0.8571
# Epoch 23/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5006 - binary_accuracy: 0.6600 - val_loss: 0.4734 - val_binary_accuracy: 0.8571
# Epoch 24/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.5203 - binary_accuracy: 0.7400 - val_loss: 0.4721 - val_binary_accuracy: 0.8571
# Epoch 25/50
# 25/25 [==============================] - 1s 27ms/step - loss: 0.5659 - binary_accuracy: 0.5800 - val_loss: 0.4714 - val_binary_accuracy: 0.8571
# Epoch 26/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.5146 - binary_accuracy: 0.8000 - val_loss: 0.4694 - val_binary_accuracy: 0.8571
# Epoch 27/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5089 - binary_accuracy: 0.6200 - val_loss: 0.4670 - val_binary_accuracy: 0.8571
# Epoch 28/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5219 - binary_accuracy: 0.7600 - val_loss: 0.4635 - val_binary_accuracy: 0.8571
# Epoch 29/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.6393 - binary_accuracy: 0.5600 - val_loss: 0.4634 - val_binary_accuracy: 0.8571
# Epoch 30/50
# 25/25 [==============================] - 1s 31ms/step - loss: 0.4909 - binary_accuracy: 0.7200 - val_loss: 0.4636 - val_binary_accuracy: 0.8571
# Epoch 31/50
# 25/25 [==============================] - 1s 31ms/step - loss: 0.4403 - binary_accuracy: 0.8000 - val_loss: 0.4620 - val_binary_accuracy: 0.8571
# Epoch 32/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.5286 - binary_accuracy: 0.6400 - val_loss: 0.4602 - val_binary_accuracy: 0.8571
# Epoch 33/50
# 25/25 [==============================] - 1s 29ms/step - loss: 0.4682 - binary_accuracy: 0.7800 - val_loss: 0.4601 - val_binary_accuracy: 0.8571
# Epoch 34/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4482 - binary_accuracy: 0.7800 - val_loss: 0.4614 - val_binary_accuracy: 0.5714
# Epoch 35/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.5033 - binary_accuracy: 0.6400 - val_loss: 0.4644 - val_binary_accuracy: 0.5714
# Epoch 36/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5614 - binary_accuracy: 0.6000 - val_loss: 0.4627 - val_binary_accuracy: 0.5714
# Epoch 37/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4600 - binary_accuracy: 0.7600 - val_loss: 0.4630 - val_binary_accuracy: 0.5714
# Epoch 38/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.4524 - binary_accuracy: 0.6800 - val_loss: 0.4601 - val_binary_accuracy: 0.5714
# Epoch 39/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4802 - binary_accuracy: 0.6400 - val_loss: 0.4538 - val_binary_accuracy: 0.5714
# Epoch 40/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5863 - binary_accuracy: 0.5800 - val_loss: 0.4455 - val_binary_accuracy: 0.8571
# Epoch 41/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5047 - binary_accuracy: 0.7800 - val_loss: 0.4405 - val_binary_accuracy: 0.8571
# Epoch 42/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.3971 - binary_accuracy: 0.8000 - val_loss: 0.4361 - val_binary_accuracy: 0.8571
# Epoch 43/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4610 - binary_accuracy: 0.6400 - val_loss: 0.4373 - val_binary_accuracy: 0.8571
# Epoch 44/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.4296 - binary_accuracy: 0.7600 - val_loss: 0.4390 - val_binary_accuracy: 0.8571
# Epoch 45/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.5072 - binary_accuracy: 0.7600 - val_loss: 0.4416 - val_binary_accuracy: 0.8571
# Epoch 46/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5175 - binary_accuracy: 0.7600 - val_loss: 0.4429 - val_binary_accuracy: 0.7143
# Epoch 47/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.4608 - binary_accuracy: 0.7200 - val_loss: 0.4476 - val_binary_accuracy: 0.5714
# Epoch 48/50
# 25/25 [==============================] - 1s 27ms/step - loss: 0.4450 - binary_accuracy: 0.7400 - val_loss: 0.4533 - val_binary_accuracy: 0.5714
# Epoch 49/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4554 - binary_accuracy: 0.8400 - val_loss: 0.4563 - val_binary_accuracy: 0.5714
# Epoch 50/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4732 - binary_accuracy: 0.6400 - val_loss: 0.4529 - val_binary_accuracy: 0.5714
# evaluating..
# fitting..
# Train on 25 samples, validate on 7 samples
# Epoch 1/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5199 - binary_accuracy: 0.6600 - val_loss: 0.2612 - val_binary_accuracy: 0.7143
# Epoch 2/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5101 - binary_accuracy: 0.6800 - val_loss: 0.2608 - val_binary_accuracy: 0.7143
# Epoch 3/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5472 - binary_accuracy: 0.6200 - val_loss: 0.2613 - val_binary_accuracy: 0.7143
# Epoch 4/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5112 - binary_accuracy: 0.7600 - val_loss: 0.2606 - val_binary_accuracy: 0.7143
# Epoch 5/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5053 - binary_accuracy: 0.6400 - val_loss: 0.2636 - val_binary_accuracy: 0.7143
# Epoch 6/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5306 - binary_accuracy: 0.7200 - val_loss: 0.2683 - val_binary_accuracy: 0.7143
# Epoch 7/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5362 - binary_accuracy: 0.6600 - val_loss: 0.2651 - val_binary_accuracy: 0.7143
# Epoch 8/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5707 - binary_accuracy: 0.5600 - val_loss: 0.2618 - val_binary_accuracy: 0.7143
# Epoch 9/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4573 - binary_accuracy: 0.7200 - val_loss: 0.2632 - val_binary_accuracy: 0.7143
# Epoch 10/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4846 - binary_accuracy: 0.6800 - val_loss: 0.2679 - val_binary_accuracy: 0.7143
# Epoch 11/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4809 - binary_accuracy: 0.6200 - val_loss: 0.2746 - val_binary_accuracy: 0.7143
# Epoch 12/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5878 - binary_accuracy: 0.6400 - val_loss: 0.2757 - val_binary_accuracy: 0.7143
# Epoch 13/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4993 - binary_accuracy: 0.6400 - val_loss: 0.2728 - val_binary_accuracy: 0.7143
# Epoch 14/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.6182 - binary_accuracy: 0.6000 - val_loss: 0.2661 - val_binary_accuracy: 0.7143
# Epoch 15/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4912 - binary_accuracy: 0.5800 - val_loss: 0.2584 - val_binary_accuracy: 0.7143
# Epoch 16/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.5307 - binary_accuracy: 0.6800 - val_loss: 0.2533 - val_binary_accuracy: 0.7143
# Epoch 17/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5554 - binary_accuracy: 0.7200 - val_loss: 0.2493 - val_binary_accuracy: 0.7143
# Epoch 18/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4972 - binary_accuracy: 0.6800 - val_loss: 0.2454 - val_binary_accuracy: 0.7143
# Epoch 19/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4983 - binary_accuracy: 0.6000 - val_loss: 0.2366 - val_binary_accuracy: 1.0000
# Epoch 20/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5373 - binary_accuracy: 0.7000 - val_loss: 0.2288 - val_binary_accuracy: 1.0000
# Epoch 21/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5453 - binary_accuracy: 0.6400 - val_loss: 0.2261 - val_binary_accuracy: 1.0000
# Epoch 22/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4766 - binary_accuracy: 0.7800 - val_loss: 0.2251 - val_binary_accuracy: 1.0000
# Epoch 23/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4922 - binary_accuracy: 0.6400 - val_loss: 0.2248 - val_binary_accuracy: 1.0000
# Epoch 24/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5042 - binary_accuracy: 0.6800 - val_loss: 0.2254 - val_binary_accuracy: 1.0000
# Epoch 25/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4216 - binary_accuracy: 0.9000 - val_loss: 0.2257 - val_binary_accuracy: 1.0000
# Epoch 26/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5026 - binary_accuracy: 0.6400 - val_loss: 0.2283 - val_binary_accuracy: 1.0000
# Epoch 27/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4876 - binary_accuracy: 0.7600 - val_loss: 0.2353 - val_binary_accuracy: 1.0000
# Epoch 28/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4636 - binary_accuracy: 0.6800 - val_loss: 0.2442 - val_binary_accuracy: 0.7143
# Epoch 29/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5114 - binary_accuracy: 0.6800 - val_loss: 0.2566 - val_binary_accuracy: 0.7143
# Epoch 30/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5730 - binary_accuracy: 0.7000 - val_loss: 0.2642 - val_binary_accuracy: 0.7143
# Epoch 31/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4925 - binary_accuracy: 0.8000 - val_loss: 0.2677 - val_binary_accuracy: 0.7143
# Epoch 32/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5308 - binary_accuracy: 0.5400 - val_loss: 0.2652 - val_binary_accuracy: 0.7143
# Epoch 33/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5495 - binary_accuracy: 0.7600 - val_loss: 0.2599 - val_binary_accuracy: 0.7143
# Epoch 34/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5117 - binary_accuracy: 0.7200 - val_loss: 0.2532 - val_binary_accuracy: 0.7143
# Epoch 35/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.5641 - binary_accuracy: 0.7600 - val_loss: 0.2488 - val_binary_accuracy: 0.7143
# Epoch 36/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5868 - binary_accuracy: 0.6600 - val_loss: 0.2442 - val_binary_accuracy: 0.7143
# Epoch 37/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5562 - binary_accuracy: 0.5600 - val_loss: 0.2436 - val_binary_accuracy: 0.7143
# Epoch 38/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.5819 - binary_accuracy: 0.5600 - val_loss: 0.2423 - val_binary_accuracy: 0.7143
# Epoch 39/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5024 - binary_accuracy: 0.6600 - val_loss: 0.2437 - val_binary_accuracy: 0.7143
# Epoch 40/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4915 - binary_accuracy: 0.6000 - val_loss: 0.2448 - val_binary_accuracy: 0.7143
# Epoch 41/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.6580 - binary_accuracy: 0.5400 - val_loss: 0.2519 - val_binary_accuracy: 0.7143
# Epoch 42/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4745 - binary_accuracy: 0.6600 - val_loss: 0.2582 - val_binary_accuracy: 0.7143
# Epoch 43/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5032 - binary_accuracy: 0.6400 - val_loss: 0.2625 - val_binary_accuracy: 0.7143
# Epoch 44/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5680 - binary_accuracy: 0.5600 - val_loss: 0.2671 - val_binary_accuracy: 0.7143
# Epoch 45/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4934 - binary_accuracy: 0.6000 - val_loss: 0.2715 - val_binary_accuracy: 0.7143
# Epoch 46/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5155 - binary_accuracy: 0.6800 - val_loss: 0.2741 - val_binary_accuracy: 0.7143
# Epoch 47/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5318 - binary_accuracy: 0.6600 - val_loss: 0.2760 - val_binary_accuracy: 0.7143
# Epoch 48/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.4951 - binary_accuracy: 0.7000 - val_loss: 0.2764 - val_binary_accuracy: 0.7143
# Epoch 49/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.5146 - binary_accuracy: 0.6600 - val_loss: 0.2768 - val_binary_accuracy: 0.7143
# Epoch 50/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4860 - binary_accuracy: 0.7400 - val_loss: 0.2768 - val_binary_accuracy: 0.7143
# evaluating..
# fitting..
# Train on 25 samples, validate on 7 samples
# Epoch 1/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4731 - binary_accuracy: 0.7000 - val_loss: 0.4458 - val_binary_accuracy: 0.5714
# Epoch 2/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.5129 - binary_accuracy: 0.6200 - val_loss: 0.4473 - val_binary_accuracy: 0.5714
# Epoch 3/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.4929 - binary_accuracy: 0.6800 - val_loss: 0.4480 - val_binary_accuracy: 0.5714
# Epoch 4/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5121 - binary_accuracy: 0.7000 - val_loss: 0.4547 - val_binary_accuracy: 0.5714
# Epoch 5/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4677 - binary_accuracy: 0.7200 - val_loss: 0.4592 - val_binary_accuracy: 0.5714
# Epoch 6/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4283 - binary_accuracy: 0.7400 - val_loss: 0.4626 - val_binary_accuracy: 0.5714
# Epoch 7/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4760 - binary_accuracy: 0.7200 - val_loss: 0.4649 - val_binary_accuracy: 0.5714
# Epoch 8/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5324 - binary_accuracy: 0.6800 - val_loss: 0.4670 - val_binary_accuracy: 0.5714
# Epoch 9/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.4647 - binary_accuracy: 0.7600 - val_loss: 0.4678 - val_binary_accuracy: 0.5714
# Epoch 10/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5109 - binary_accuracy: 0.7400 - val_loss: 0.4684 - val_binary_accuracy: 0.5714
# Epoch 11/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4343 - binary_accuracy: 0.6800 - val_loss: 0.4688 - val_binary_accuracy: 0.5714
# Epoch 12/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4613 - binary_accuracy: 0.7200 - val_loss: 0.4696 - val_binary_accuracy: 0.5714
# Epoch 13/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4235 - binary_accuracy: 0.7400 - val_loss: 0.4703 - val_binary_accuracy: 0.5714
# Epoch 14/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5231 - binary_accuracy: 0.6800 - val_loss: 0.4679 - val_binary_accuracy: 0.5714
# Epoch 15/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.4675 - binary_accuracy: 0.6800 - val_loss: 0.4636 - val_binary_accuracy: 0.5714
# Epoch 16/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4652 - binary_accuracy: 0.7200 - val_loss: 0.4598 - val_binary_accuracy: 0.5714
# Epoch 17/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4888 - binary_accuracy: 0.6400 - val_loss: 0.4569 - val_binary_accuracy: 0.5714
# Epoch 18/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4757 - binary_accuracy: 0.7000 - val_loss: 0.4531 - val_binary_accuracy: 0.5714
# Epoch 19/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4549 - binary_accuracy: 0.7400 - val_loss: 0.4488 - val_binary_accuracy: 0.5714
# Epoch 20/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4584 - binary_accuracy: 0.6800 - val_loss: 0.4428 - val_binary_accuracy: 0.5714
# Epoch 21/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4651 - binary_accuracy: 0.7200 - val_loss: 0.4358 - val_binary_accuracy: 0.5714
# Epoch 22/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4640 - binary_accuracy: 0.7600 - val_loss: 0.4300 - val_binary_accuracy: 0.5714
# Epoch 23/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4385 - binary_accuracy: 0.6800 - val_loss: 0.4238 - val_binary_accuracy: 0.5714
# Epoch 24/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4028 - binary_accuracy: 0.8400 - val_loss: 0.4195 - val_binary_accuracy: 0.5714
# Epoch 25/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.4656 - binary_accuracy: 0.7000 - val_loss: 0.4156 - val_binary_accuracy: 0.5714
# Epoch 26/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5157 - binary_accuracy: 0.7000 - val_loss: 0.4143 - val_binary_accuracy: 0.5714
# Epoch 27/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.4487 - binary_accuracy: 0.7000 - val_loss: 0.4126 - val_binary_accuracy: 0.5714
# Epoch 28/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4449 - binary_accuracy: 0.8000 - val_loss: 0.4137 - val_binary_accuracy: 0.5714
# Epoch 29/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.5540 - binary_accuracy: 0.5800 - val_loss: 0.4157 - val_binary_accuracy: 0.5714
# Epoch 30/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5068 - binary_accuracy: 0.7000 - val_loss: 0.4179 - val_binary_accuracy: 0.5714
# Epoch 31/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5095 - binary_accuracy: 0.7400 - val_loss: 0.4204 - val_binary_accuracy: 0.5714
# Epoch 32/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4538 - binary_accuracy: 0.7600 - val_loss: 0.4220 - val_binary_accuracy: 0.5714
# Epoch 33/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4346 - binary_accuracy: 0.7600 - val_loss: 0.4227 - val_binary_accuracy: 0.5714
# Epoch 34/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4205 - binary_accuracy: 0.8000 - val_loss: 0.4227 - val_binary_accuracy: 0.5714
# Epoch 35/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4545 - binary_accuracy: 0.6800 - val_loss: 0.4227 - val_binary_accuracy: 0.5714
# Epoch 36/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4111 - binary_accuracy: 0.8000 - val_loss: 0.4238 - val_binary_accuracy: 0.5714
# Epoch 37/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5575 - binary_accuracy: 0.5800 - val_loss: 0.4205 - val_binary_accuracy: 0.5714
# Epoch 38/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4258 - binary_accuracy: 0.8000 - val_loss: 0.4161 - val_binary_accuracy: 0.5714
# Epoch 39/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4034 - binary_accuracy: 0.8000 - val_loss: 0.4117 - val_binary_accuracy: 0.5714
# Epoch 40/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4870 - binary_accuracy: 0.7000 - val_loss: 0.4083 - val_binary_accuracy: 0.5714
# Epoch 41/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5111 - binary_accuracy: 0.6800 - val_loss: 0.4042 - val_binary_accuracy: 0.7143
# Epoch 42/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.3912 - binary_accuracy: 0.8600 - val_loss: 0.4012 - val_binary_accuracy: 0.7143
# Epoch 43/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4404 - binary_accuracy: 0.5600 - val_loss: 0.3986 - val_binary_accuracy: 0.8571
# Epoch 44/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4361 - binary_accuracy: 0.6000 - val_loss: 0.3976 - val_binary_accuracy: 0.8571
# Epoch 45/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4410 - binary_accuracy: 0.7200 - val_loss: 0.3985 - val_binary_accuracy: 0.8571
# Epoch 46/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4390 - binary_accuracy: 0.7600 - val_loss: 0.3991 - val_binary_accuracy: 0.8571
# Epoch 47/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4088 - binary_accuracy: 0.8000 - val_loss: 0.4027 - val_binary_accuracy: 0.7143
# Epoch 48/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4445 - binary_accuracy: 0.6400 - val_loss: 0.4057 - val_binary_accuracy: 0.7143
# Epoch 49/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4730 - binary_accuracy: 0.7400 - val_loss: 0.4079 - val_binary_accuracy: 0.5714
# Epoch 50/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4425 - binary_accuracy: 0.6400 - val_loss: 0.4071 - val_binary_accuracy: 0.5714
# evaluating..
# fitting..
# Train on 25 samples, validate on 7 samples
# Epoch 1/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4884 - binary_accuracy: 0.7200 - val_loss: 0.4027 - val_binary_accuracy: 0.7857
# Epoch 2/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4910 - binary_accuracy: 0.7000 - val_loss: 0.4023 - val_binary_accuracy: 0.7143
# Epoch 3/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.4914 - binary_accuracy: 0.7600 - val_loss: 0.4022 - val_binary_accuracy: 0.7143
# Epoch 4/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4900 - binary_accuracy: 0.6400 - val_loss: 0.4024 - val_binary_accuracy: 0.7143
# Epoch 5/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4606 - binary_accuracy: 0.6600 - val_loss: 0.4035 - val_binary_accuracy: 0.7143
# Epoch 6/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5429 - binary_accuracy: 0.5400 - val_loss: 0.4055 - val_binary_accuracy: 0.7143
# Epoch 7/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5121 - binary_accuracy: 0.6800 - val_loss: 0.4092 - val_binary_accuracy: 0.7143
# Epoch 8/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4849 - binary_accuracy: 0.7200 - val_loss: 0.4111 - val_binary_accuracy: 0.7143
# Epoch 9/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5160 - binary_accuracy: 0.5800 - val_loss: 0.4150 - val_binary_accuracy: 0.7143
# Epoch 10/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4274 - binary_accuracy: 0.7800 - val_loss: 0.4190 - val_binary_accuracy: 0.7143
# Epoch 11/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4934 - binary_accuracy: 0.7600 - val_loss: 0.4209 - val_binary_accuracy: 0.7143
# Epoch 12/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4927 - binary_accuracy: 0.6600 - val_loss: 0.4206 - val_binary_accuracy: 0.7143
# Epoch 13/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4526 - binary_accuracy: 0.7800 - val_loss: 0.4216 - val_binary_accuracy: 0.7143
# Epoch 14/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5212 - binary_accuracy: 0.6600 - val_loss: 0.4213 - val_binary_accuracy: 0.7143
# Epoch 15/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.6566 - binary_accuracy: 0.6600 - val_loss: 0.4206 - val_binary_accuracy: 0.7143
# Epoch 16/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5231 - binary_accuracy: 0.6600 - val_loss: 0.4231 - val_binary_accuracy: 0.7143
# Epoch 17/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4858 - binary_accuracy: 0.7200 - val_loss: 0.4233 - val_binary_accuracy: 0.7143
# Epoch 18/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4785 - binary_accuracy: 0.7400 - val_loss: 0.4240 - val_binary_accuracy: 0.7143
# Epoch 19/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4822 - binary_accuracy: 0.7200 - val_loss: 0.4240 - val_binary_accuracy: 0.7143
# Epoch 20/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.6217 - binary_accuracy: 0.7200 - val_loss: 0.4184 - val_binary_accuracy: 0.7143
# Epoch 21/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5099 - binary_accuracy: 0.7200 - val_loss: 0.4129 - val_binary_accuracy: 0.7143
# Epoch 22/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4959 - binary_accuracy: 0.6400 - val_loss: 0.4089 - val_binary_accuracy: 0.7143
# Epoch 23/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.4751 - binary_accuracy: 0.7000 - val_loss: 0.4068 - val_binary_accuracy: 0.7143
# Epoch 24/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4876 - binary_accuracy: 0.7200 - val_loss: 0.4055 - val_binary_accuracy: 0.7143
# Epoch 25/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4880 - binary_accuracy: 0.7400 - val_loss: 0.4048 - val_binary_accuracy: 0.7143
# Epoch 26/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4699 - binary_accuracy: 0.6800 - val_loss: 0.4046 - val_binary_accuracy: 0.7143
# Epoch 27/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.5481 - binary_accuracy: 0.6800 - val_loss: 0.4046 - val_binary_accuracy: 0.7143
# Epoch 28/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5425 - binary_accuracy: 0.6400 - val_loss: 0.4049 - val_binary_accuracy: 0.7143
# Epoch 29/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5268 - binary_accuracy: 0.6400 - val_loss: 0.4051 - val_binary_accuracy: 0.7143
# Epoch 30/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4917 - binary_accuracy: 0.6800 - val_loss: 0.4053 - val_binary_accuracy: 0.7143
# Epoch 31/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4761 - binary_accuracy: 0.7200 - val_loss: 0.4053 - val_binary_accuracy: 0.7143
# Epoch 32/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.4920 - binary_accuracy: 0.7400 - val_loss: 0.4053 - val_binary_accuracy: 0.7143
# Epoch 33/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.5559 - binary_accuracy: 0.5400 - val_loss: 0.4053 - val_binary_accuracy: 0.7857
# Epoch 34/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5149 - binary_accuracy: 0.6800 - val_loss: 0.4055 - val_binary_accuracy: 0.7143
# Epoch 35/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5034 - binary_accuracy: 0.6600 - val_loss: 0.4057 - val_binary_accuracy: 0.7143
# Epoch 36/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4830 - binary_accuracy: 0.6400 - val_loss: 0.4061 - val_binary_accuracy: 0.7143
# Epoch 37/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5252 - binary_accuracy: 0.6600 - val_loss: 0.4072 - val_binary_accuracy: 0.7143
# Epoch 38/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5224 - binary_accuracy: 0.6400 - val_loss: 0.4086 - val_binary_accuracy: 0.7143
# Epoch 39/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5279 - binary_accuracy: 0.5000 - val_loss: 0.4104 - val_binary_accuracy: 0.7143
# Epoch 40/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4891 - binary_accuracy: 0.7600 - val_loss: 0.4123 - val_binary_accuracy: 0.7143
# Epoch 41/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4624 - binary_accuracy: 0.7400 - val_loss: 0.4147 - val_binary_accuracy: 0.7143
# Epoch 42/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4658 - binary_accuracy: 0.7600 - val_loss: 0.4175 - val_binary_accuracy: 0.7143
# Epoch 43/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4951 - binary_accuracy: 0.7200 - val_loss: 0.4203 - val_binary_accuracy: 0.7143
# Epoch 44/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.5828 - binary_accuracy: 0.7000 - val_loss: 0.4225 - val_binary_accuracy: 0.7143
# Epoch 45/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4821 - binary_accuracy: 0.7200 - val_loss: 0.4243 - val_binary_accuracy: 0.7143
# Epoch 46/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5063 - binary_accuracy: 0.7200 - val_loss: 0.4252 - val_binary_accuracy: 0.7143
# Epoch 47/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4092 - binary_accuracy: 0.7200 - val_loss: 0.4265 - val_binary_accuracy: 0.7143
# Epoch 48/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4846 - binary_accuracy: 0.7200 - val_loss: 0.4268 - val_binary_accuracy: 0.7143
# Epoch 49/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5068 - binary_accuracy: 0.7200 - val_loss: 0.4260 - val_binary_accuracy: 0.7143
# Epoch 50/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5168 - binary_accuracy: 0.7200 - val_loss: 0.4241 - val_binary_accuracy: 0.7143
# evaluating..
# fitting..
# Train on 25 samples, validate on 7 samples
# Epoch 1/50
# 25/25 [==============================] - 0s 16ms/step - loss: 0.4313 - binary_accuracy: 0.8000 - val_loss: 0.6445 - val_binary_accuracy: 0.4286
# Epoch 2/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4139 - binary_accuracy: 0.8000 - val_loss: 0.6438 - val_binary_accuracy: 0.4286
# Epoch 3/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4556 - binary_accuracy: 0.8000 - val_loss: 0.6457 - val_binary_accuracy: 0.4286
# Epoch 4/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4509 - binary_accuracy: 0.7600 - val_loss: 0.6498 - val_binary_accuracy: 0.4286
# Epoch 5/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4216 - binary_accuracy: 0.8000 - val_loss: 0.6560 - val_binary_accuracy: 0.4286
# Epoch 6/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4309 - binary_accuracy: 0.8000 - val_loss: 0.6608 - val_binary_accuracy: 0.4286
# Epoch 7/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4342 - binary_accuracy: 0.7200 - val_loss: 0.6693 - val_binary_accuracy: 0.4286
# Epoch 8/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4308 - binary_accuracy: 0.8000 - val_loss: 0.6769 - val_binary_accuracy: 0.4286
# Epoch 9/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.3644 - binary_accuracy: 0.8000 - val_loss: 0.6862 - val_binary_accuracy: 0.4286
# Epoch 10/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5415 - binary_accuracy: 0.7600 - val_loss: 0.6872 - val_binary_accuracy: 0.4286
# Epoch 11/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.4062 - binary_accuracy: 0.8400 - val_loss: 0.6883 - val_binary_accuracy: 0.4286
# Epoch 12/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4302 - binary_accuracy: 0.8000 - val_loss: 0.6806 - val_binary_accuracy: 0.4286
# Epoch 13/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4193 - binary_accuracy: 0.8000 - val_loss: 0.6787 - val_binary_accuracy: 0.4286
# Epoch 14/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4238 - binary_accuracy: 0.8000 - val_loss: 0.6714 - val_binary_accuracy: 0.4286
# Epoch 15/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4336 - binary_accuracy: 0.8400 - val_loss: 0.6557 - val_binary_accuracy: 0.4286
# Epoch 16/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.3989 - binary_accuracy: 0.8000 - val_loss: 0.6480 - val_binary_accuracy: 0.4286
# Epoch 17/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.4422 - binary_accuracy: 0.8000 - val_loss: 0.6429 - val_binary_accuracy: 0.4286
# Epoch 18/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4425 - binary_accuracy: 0.8000 - val_loss: 0.6411 - val_binary_accuracy: 0.4286
# Epoch 19/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.4018 - binary_accuracy: 0.7600 - val_loss: 0.6413 - val_binary_accuracy: 0.4286
# Epoch 20/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4629 - binary_accuracy: 0.8000 - val_loss: 0.6386 - val_binary_accuracy: 0.4286
# Epoch 21/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4193 - binary_accuracy: 0.8000 - val_loss: 0.6400 - val_binary_accuracy: 0.4286
# Epoch 22/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3101 - binary_accuracy: 0.8800 - val_loss: 0.6425 - val_binary_accuracy: 0.4286
# Epoch 23/50
# 25/25 [==============================] - 1s 28ms/step - loss: 0.4010 - binary_accuracy: 0.7600 - val_loss: 0.6439 - val_binary_accuracy: 0.4286
# Epoch 24/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.4385 - binary_accuracy: 0.7600 - val_loss: 0.6525 - val_binary_accuracy: 0.4286
# Epoch 25/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.3789 - binary_accuracy: 0.8000 - val_loss: 0.6612 - val_binary_accuracy: 0.4286
# Epoch 26/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.4196 - binary_accuracy: 0.8000 - val_loss: 0.6677 - val_binary_accuracy: 0.4286
# Epoch 27/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.4162 - binary_accuracy: 0.7600 - val_loss: 0.6790 - val_binary_accuracy: 0.4286
# Epoch 28/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4622 - binary_accuracy: 0.7600 - val_loss: 0.6919 - val_binary_accuracy: 0.4286
# Epoch 29/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4031 - binary_accuracy: 0.8000 - val_loss: 0.7053 - val_binary_accuracy: 0.4286
# Epoch 30/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.3415 - binary_accuracy: 0.8400 - val_loss: 0.7187 - val_binary_accuracy: 0.4286
# Epoch 31/50
# 25/25 [==============================] - 1s 28ms/step - loss: 0.4222 - binary_accuracy: 0.8000 - val_loss: 0.7303 - val_binary_accuracy: 0.4286
# Epoch 32/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4381 - binary_accuracy: 0.7600 - val_loss: 0.7434 - val_binary_accuracy: 0.4286
# Epoch 33/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4881 - binary_accuracy: 0.8000 - val_loss: 0.7478 - val_binary_accuracy: 0.4286
# Epoch 34/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4483 - binary_accuracy: 0.7600 - val_loss: 0.7502 - val_binary_accuracy: 0.4286
# Epoch 35/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4169 - binary_accuracy: 0.8000 - val_loss: 0.7532 - val_binary_accuracy: 0.4286
# Epoch 36/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.4571 - binary_accuracy: 0.8000 - val_loss: 0.7487 - val_binary_accuracy: 0.4286
# Epoch 37/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.4367 - binary_accuracy: 0.8000 - val_loss: 0.7441 - val_binary_accuracy: 0.4286
# Epoch 38/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.4288 - binary_accuracy: 0.7600 - val_loss: 0.7400 - val_binary_accuracy: 0.4286
# Epoch 39/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.4085 - binary_accuracy: 0.8000 - val_loss: 0.7344 - val_binary_accuracy: 0.4286
# Epoch 40/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.3548 - binary_accuracy: 0.8400 - val_loss: 0.7299 - val_binary_accuracy: 0.4286
# Epoch 41/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4309 - binary_accuracy: 0.7600 - val_loss: 0.7249 - val_binary_accuracy: 0.4286
# Epoch 42/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4285 - binary_accuracy: 0.8000 - val_loss: 0.7208 - val_binary_accuracy: 0.4286
# Epoch 43/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4231 - binary_accuracy: 0.8000 - val_loss: 0.7166 - val_binary_accuracy: 0.4286
# Epoch 44/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4827 - binary_accuracy: 0.8000 - val_loss: 0.7053 - val_binary_accuracy: 0.4286
# Epoch 45/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.4075 - binary_accuracy: 0.8000 - val_loss: 0.6957 - val_binary_accuracy: 0.4286
# Epoch 46/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4258 - binary_accuracy: 0.8000 - val_loss: 0.6875 - val_binary_accuracy: 0.4286
# Epoch 47/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3993 - binary_accuracy: 0.8000 - val_loss: 0.6820 - val_binary_accuracy: 0.4286
# Epoch 48/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.4475 - binary_accuracy: 0.8000 - val_loss: 0.6778 - val_binary_accuracy: 0.4286
# Epoch 49/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3995 - binary_accuracy: 0.8000 - val_loss: 0.6760 - val_binary_accuracy: 0.4286
# Epoch 50/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4060 - binary_accuracy: 0.8000 - val_loss: 0.6760 - val_binary_accuracy: 0.4286
# evaluating..
# fitting..
# Train on 25 samples, validate on 7 samples
# Epoch 1/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4625 - binary_accuracy: 0.7200 - val_loss: 0.5224 - val_binary_accuracy: 0.5714
# Epoch 2/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.5851 - binary_accuracy: 0.6800 - val_loss: 0.5196 - val_binary_accuracy: 0.5714
# Epoch 3/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4895 - binary_accuracy: 0.7400 - val_loss: 0.5188 - val_binary_accuracy: 0.5714
# Epoch 4/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4131 - binary_accuracy: 0.7600 - val_loss: 0.5178 - val_binary_accuracy: 0.5714
# Epoch 5/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4294 - binary_accuracy: 0.7600 - val_loss: 0.5162 - val_binary_accuracy: 0.5714
# Epoch 6/50
# ...
# Epoch 50/50
# 25/25 [==============================] - 1s 30ms/step - loss: 0.2912 - binary_accuracy: 0.8800 - val_loss: 0.3395 - val_binary_accuracy: 0.8571
# evaluating..
# fitting..
# Train on 25 samples, validate on 7 samples
# Epoch 1/50
# 25/25 [==============================] - 1s 32ms/step - loss: 0.3788 - binary_accuracy: 0.7600 - val_loss: 0.3176 - val_binary_accuracy: 1.0000
# Epoch 2/50
# 25/25 [==============================] - 1s 27ms/step - loss: 0.3704 - binary_accuracy: 0.7600 - val_loss: 0.3181 - val_binary_accuracy: 1.0000
# Epoch 3/50
# 25/25 [==============================] - 1s 30ms/step - loss: 0.3227 - binary_accuracy: 0.8000 - val_loss: 0.3193 - val_binary_accuracy: 1.0000
# Epoch 4/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.2796 - binary_accuracy: 0.8400 - val_loss: 0.3205 - val_binary_accuracy: 1.0000
# Epoch 5/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.4325 - binary_accuracy: 0.7000 - val_loss: 0.3217 - val_binary_accuracy: 1.0000
# Epoch 6/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.2613 - binary_accuracy: 0.8800 - val_loss: 0.3228 - val_binary_accuracy: 1.0000
# Epoch 7/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.2367 - binary_accuracy: 0.8800 - val_loss: 0.3237 - val_binary_accuracy: 1.0000
# Epoch 8/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.2317 - binary_accuracy: 0.8800 - val_loss: 0.3245 - val_binary_accuracy: 1.0000
# Epoch 9/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.3651 - binary_accuracy: 0.7200 - val_loss: 0.3257 - val_binary_accuracy: 1.0000
# Epoch 10/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3161 - binary_accuracy: 0.8000 - val_loss: 0.3269 - val_binary_accuracy: 1.0000
# Epoch 11/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.3463 - binary_accuracy: 0.7600 - val_loss: 0.3283 - val_binary_accuracy: 1.0000
# Epoch 12/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2727 - binary_accuracy: 0.8400 - val_loss: 0.3297 - val_binary_accuracy: 1.0000
# Epoch 13/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.3109 - binary_accuracy: 0.8000 - val_loss: 0.3311 - val_binary_accuracy: 1.0000
# Epoch 14/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.2881 - binary_accuracy: 0.8400 - val_loss: 0.3325 - val_binary_accuracy: 1.0000
# Epoch 15/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.3540 - binary_accuracy: 0.7600 - val_loss: 0.3341 - val_binary_accuracy: 1.0000
# Epoch 16/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.2977 - binary_accuracy: 0.8400 - val_loss: 0.3357 - val_binary_accuracy: 1.0000
# Epoch 17/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.3763 - binary_accuracy: 0.7600 - val_loss: 0.3376 - val_binary_accuracy: 1.0000
# Epoch 18/50
# 25/25 [==============================] - 1s 26ms/step - loss: 0.2300 - binary_accuracy: 0.8800 - val_loss: 0.3392 - val_binary_accuracy: 1.0000
# Epoch 19/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.3453 - binary_accuracy: 0.8000 - val_loss: 0.3403 - val_binary_accuracy: 1.0000
# Epoch 20/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.2904 - binary_accuracy: 0.8400 - val_loss: 0.3414 - val_binary_accuracy: 1.0000
# Epoch 21/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4492 - binary_accuracy: 0.7400 - val_loss: 0.3426 - val_binary_accuracy: 1.0000
# Epoch 22/50
# 25/25 [==============================] - 1s 27ms/step - loss: 0.4514 - binary_accuracy: 0.6200 - val_loss: 0.3443 - val_binary_accuracy: 1.0000
# Epoch 23/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.3952 - binary_accuracy: 0.6800 - val_loss: 0.3463 - val_binary_accuracy: 1.0000
# Epoch 24/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.2936 - binary_accuracy: 0.8400 - val_loss: 0.3482 - val_binary_accuracy: 1.0000
# Epoch 25/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.2057 - binary_accuracy: 0.9200 - val_loss: 0.3499 - val_binary_accuracy: 1.0000
# Epoch 26/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4244 - binary_accuracy: 0.6800 - val_loss: 0.3521 - val_binary_accuracy: 1.0000
# Epoch 27/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.4879 - binary_accuracy: 0.7200 - val_loss: 0.3545 - val_binary_accuracy: 1.0000
# Epoch 28/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.2777 - binary_accuracy: 0.8400 - val_loss: 0.3568 - val_binary_accuracy: 1.0000
# Epoch 29/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.3404 - binary_accuracy: 0.8000 - val_loss: 0.3592 - val_binary_accuracy: 1.0000
# Epoch 30/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.3513 - binary_accuracy: 0.7600 - val_loss: 0.3616 - val_binary_accuracy: 1.0000
# Epoch 31/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.2947 - binary_accuracy: 0.8000 - val_loss: 0.3640 - val_binary_accuracy: 1.0000
# Epoch 32/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.3253 - binary_accuracy: 0.8800 - val_loss: 0.3661 - val_binary_accuracy: 1.0000
# Epoch 33/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2695 - binary_accuracy: 0.8400 - val_loss: 0.3678 - val_binary_accuracy: 1.0000
# Epoch 34/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.3138 - binary_accuracy: 0.8400 - val_loss: 0.3694 - val_binary_accuracy: 1.0000
# Epoch 35/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.3592 - binary_accuracy: 0.7200 - val_loss: 0.3713 - val_binary_accuracy: 1.0000
# Epoch 36/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4343 - binary_accuracy: 0.7200 - val_loss: 0.3733 - val_binary_accuracy: 1.0000
# Epoch 37/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2707 - binary_accuracy: 0.8400 - val_loss: 0.3751 - val_binary_accuracy: 1.0000
# Epoch 38/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2318 - binary_accuracy: 0.8800 - val_loss: 0.3768 - val_binary_accuracy: 1.0000
# Epoch 39/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.3771 - binary_accuracy: 0.7200 - val_loss: 0.3785 - val_binary_accuracy: 1.0000
# Epoch 40/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.2689 - binary_accuracy: 0.8400 - val_loss: 0.3801 - val_binary_accuracy: 1.0000
# Epoch 41/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.2669 - binary_accuracy: 0.8200 - val_loss: 0.3815 - val_binary_accuracy: 1.0000
# Epoch 42/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.3032 - binary_accuracy: 0.8800 - val_loss: 0.3828 - val_binary_accuracy: 1.0000
# Epoch 43/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3433 - binary_accuracy: 0.7600 - val_loss: 0.3841 - val_binary_accuracy: 1.0000
# Epoch 44/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.3081 - binary_accuracy: 0.8000 - val_loss: 0.3854 - val_binary_accuracy: 1.0000
# Epoch 45/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2911 - binary_accuracy: 0.8000 - val_loss: 0.3866 - val_binary_accuracy: 1.0000
# Epoch 46/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.3303 - binary_accuracy: 0.8000 - val_loss: 0.3881 - val_binary_accuracy: 1.0000
# Epoch 47/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.5628 - binary_accuracy: 0.7600 - val_loss: 0.3896 - val_binary_accuracy: 1.0000
# Epoch 48/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.3026 - binary_accuracy: 0.8400 - val_loss: 0.3912 - val_binary_accuracy: 1.0000
# Epoch 49/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.3850 - binary_accuracy: 0.8400 - val_loss: 0.3926 - val_binary_accuracy: 1.0000
# Epoch 50/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.3008 - binary_accuracy: 0.8000 - val_loss: 0.3932 - val_binary_accuracy: 1.0000
# evaluating..
# fitting..
# Train on 25 samples, validate on 7 samples
# Epoch 1/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.2999 - binary_accuracy: 0.8200 - val_loss: 0.3616 - val_binary_accuracy: 0.8571
# Epoch 2/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.3565 - binary_accuracy: 0.8000 - val_loss: 0.3616 - val_binary_accuracy: 0.8571
# Epoch 3/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.3047 - binary_accuracy: 0.8400 - val_loss: 0.3616 - val_binary_accuracy: 0.8571
# Epoch 4/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.3365 - binary_accuracy: 0.8400 - val_loss: 0.3616 - val_binary_accuracy: 0.8571
# Epoch 5/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.3102 - binary_accuracy: 0.8400 - val_loss: 0.3615 - val_binary_accuracy: 0.8571
# Epoch 6/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.3282 - binary_accuracy: 0.8000 - val_loss: 0.3613 - val_binary_accuracy: 0.8571
# Epoch 7/50
# 25/25 [==============================] - 1s 24ms/step - loss: 0.3739 - binary_accuracy: 0.7800 - val_loss: 0.3612 - val_binary_accuracy: 0.8571
# Epoch 8/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4483 - binary_accuracy: 0.7200 - val_loss: 0.3612 - val_binary_accuracy: 0.8571
# Epoch 9/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.2959 - binary_accuracy: 0.8800 - val_loss: 0.3612 - val_binary_accuracy: 0.8571
# Epoch 10/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4831 - binary_accuracy: 0.8000 - val_loss: 0.3611 - val_binary_accuracy: 0.8571
# Epoch 11/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.3307 - binary_accuracy: 0.8000 - val_loss: 0.3610 - val_binary_accuracy: 0.8571
# Epoch 12/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2895 - binary_accuracy: 0.8800 - val_loss: 0.3608 - val_binary_accuracy: 0.8571
# Epoch 13/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3272 - binary_accuracy: 0.8000 - val_loss: 0.3605 - val_binary_accuracy: 0.8571
# Epoch 14/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.3373 - binary_accuracy: 0.8400 - val_loss: 0.3602 - val_binary_accuracy: 0.8571
# Epoch 15/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.3567 - binary_accuracy: 0.7400 - val_loss: 0.3599 - val_binary_accuracy: 0.8571
# Epoch 16/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.2934 - binary_accuracy: 0.8600 - val_loss: 0.3594 - val_binary_accuracy: 0.8571
# Epoch 17/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2907 - binary_accuracy: 0.8800 - val_loss: 0.3590 - val_binary_accuracy: 0.8571
# Epoch 18/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3605 - binary_accuracy: 0.8000 - val_loss: 0.3586 - val_binary_accuracy: 0.8571
# Epoch 19/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3380 - binary_accuracy: 0.8000 - val_loss: 0.3581 - val_binary_accuracy: 0.8571
# Epoch 20/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4143 - binary_accuracy: 0.8600 - val_loss: 0.3577 - val_binary_accuracy: 0.8571
# Epoch 21/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.3760 - binary_accuracy: 0.7600 - val_loss: 0.3574 - val_binary_accuracy: 0.8571
# Epoch 22/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.3556 - binary_accuracy: 0.8000 - val_loss: 0.3570 - val_binary_accuracy: 0.8571
# Epoch 23/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.3407 - binary_accuracy: 0.8400 - val_loss: 0.3567 - val_binary_accuracy: 0.8571
# Epoch 24/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.3433 - binary_accuracy: 0.8000 - val_loss: 0.3564 - val_binary_accuracy: 0.8571
# Epoch 25/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.2825 - binary_accuracy: 0.9200 - val_loss: 0.3559 - val_binary_accuracy: 0.8571
# Epoch 26/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4776 - binary_accuracy: 0.7000 - val_loss: 0.3557 - val_binary_accuracy: 0.8571
# Epoch 27/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.2988 - binary_accuracy: 0.8400 - val_loss: 0.3554 - val_binary_accuracy: 0.8571
# Epoch 28/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.3157 - binary_accuracy: 0.8400 - val_loss: 0.3551 - val_binary_accuracy: 0.8571
# Epoch 29/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4580 - binary_accuracy: 0.8400 - val_loss: 0.3547 - val_binary_accuracy: 0.8571
# Epoch 30/50
# 25/25 [==============================] - 1s 23ms/step - loss: 0.4014 - binary_accuracy: 0.8400 - val_loss: 0.3544 - val_binary_accuracy: 0.8571
# Epoch 31/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3246 - binary_accuracy: 0.8000 - val_loss: 0.3540 - val_binary_accuracy: 0.8571
# Epoch 32/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.2865 - binary_accuracy: 0.8800 - val_loss: 0.3535 - val_binary_accuracy: 0.8571
# Epoch 33/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.3381 - binary_accuracy: 0.8400 - val_loss: 0.3531 - val_binary_accuracy: 0.8571
# Epoch 34/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.3841 - binary_accuracy: 0.7200 - val_loss: 0.3527 - val_binary_accuracy: 0.8571
# Epoch 35/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.4691 - binary_accuracy: 0.7600 - val_loss: 0.3525 - val_binary_accuracy: 0.8571
# Epoch 36/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.3286 - binary_accuracy: 0.8000 - val_loss: 0.3524 - val_binary_accuracy: 0.8571
# Epoch 37/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.2324 - binary_accuracy: 0.9200 - val_loss: 0.3521 - val_binary_accuracy: 0.8571
# Epoch 38/50
# 25/25 [==============================] - 0s 18ms/step - loss: 0.4736 - binary_accuracy: 0.7600 - val_loss: 0.3519 - val_binary_accuracy: 0.8571
# Epoch 39/50
# 25/25 [==============================] - 1s 22ms/step - loss: 0.4716 - binary_accuracy: 0.7200 - val_loss: 0.3518 - val_binary_accuracy: 0.8571
# Epoch 40/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.3049 - binary_accuracy: 0.8400 - val_loss: 0.3516 - val_binary_accuracy: 0.8571
# Epoch 41/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.5319 - binary_accuracy: 0.7600 - val_loss: 0.3515 - val_binary_accuracy: 0.8571
# Epoch 42/50
# 25/25 [==============================] - 1s 25ms/step - loss: 0.3729 - binary_accuracy: 0.7600 - val_loss: 0.3515 - val_binary_accuracy: 0.8571
# Epoch 43/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3167 - binary_accuracy: 0.8400 - val_loss: 0.3515 - val_binary_accuracy: 0.8571
# Epoch 44/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.3321 - binary_accuracy: 0.8000 - val_loss: 0.3514 - val_binary_accuracy: 0.8571
# Epoch 45/50
# 25/25 [==============================] - 0s 17ms/step - loss: 0.3545 - binary_accuracy: 0.8000 - val_loss: 0.3514 - val_binary_accuracy: 0.8571
# Epoch 46/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.4414 - binary_accuracy: 0.7600 - val_loss: 0.3515 - val_binary_accuracy: 0.8571
# Epoch 47/50
# 25/25 [==============================] - 1s 20ms/step - loss: 0.3535 - binary_accuracy: 0.8400 - val_loss: 0.3515 - val_binary_accuracy: 0.8571
# Epoch 48/50
# 25/25 [==============================] - 0s 20ms/step - loss: 0.3240 - binary_accuracy: 0.9200 - val_loss: 0.3515 - val_binary_accuracy: 0.8571
# Epoch 49/50
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2487 - binary_accuracy: 0.9200 - val_loss: 0.3514 - val_binary_accuracy: 0.8571
# Epoch 50/50
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3141 - binary_accuracy: 0.8400 - val_loss: 0.3513 - val_binary_accuracy: 0.8571
# evaluating..

# %%
def calc_p_val(stats, h0, n_iterations):
  '''
  finds the p value for the results

  '''
  # calc pval
  tset, pval = ttest_1samp(stats, h0)

  return pval

p_val=calc_p_val(accuracy, .5)

# %%
def plot_p_value(stats, p_val):
  '''
  plots the bootstrapping results with the null hypothesis value
  '''

  plt.hist(stats, label='bootstrapped test')
  plt.vlines(.5, 0, 40, color='white', label='p-val= {}'.format(p_val))
  plt.vlines(.5, 0, 40, color='navy', label='Null hypothesis (50%)')

  plt.title('Histogram model accuracy bootstrapping')
  plt.xlabel('Model accuracy')
  plt.ylabel('#')
  plt.legend()
  plt.plot()

plot_p_value(accuracy, p_val)

# %%
def plot_roc_curve(fpr_vals, tpr_vals, roc_auc, p_val):
  '''
  This function plots the median value of the roc for the boostrapped
    results calculated above.

  fpr stand for false-positive rate
  tpr stands for true-positive rate
  roc_auc is the area under curve
  '''

  ## get the values
  N=len(fpr_vals)
  tprs=[]
  median_fpr=np.linspace(0, 1, 100)
  tprs=[interp(median_fpr, fpr_vals[i], tpr_vals[i]) for i in range(N)]
  std_tpr = np.std(tprs, axis=0)

  mean_tpr = np.mean(tprs, axis=0)
  median_tpr=np.median(tprs, axis=0)
  median_tpr[-1] = 1.0

  tprs_upper_2 = np.minimum(mean_tpr + 2*std_tpr, 1)
  tprs_lower_2 = np.maximum(mean_tpr - 2*std_tpr, 0)

  tprs_upper_1 = np.minimum(mean_tpr + std_tpr, 1)
  tprs_lower_1 = np.maximum(mean_tpr - std_tpr, 0)

  median_auc_roc=np.median(roc_auc)


  ## plot
  if p_val<0.05:
    p_val=0.05
  plt.plot(median_fpr, median_tpr, color='cadetblue',
           label='ROC curve \narea={} \np-val<{}'.\
            format(np.round(median_auc_roc,2),
                   np.round(p_val,2)))
  plt.fill_between(median_fpr, tprs_lower_2, tprs_upper_2, color='grey', alpha=.2,
                 label=r'$\pm$ 1 std. dev.')

  plt.fill_between(median_fpr, tprs_lower_1, tprs_upper_1, color='cadetblue', alpha=.2,
                 label=r'$\pm$ 2 std. dev.')

  plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label=r'chance')

  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('Receiver operating characteristic curve')
  plt.legend(loc="lower right")

  plt.show()



plot_roc_curve(roc_msrmnts_fpr, roc_msrmnts_tpr, accuracy,p_val)
